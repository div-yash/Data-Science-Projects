# %% [markdown]
# <a href="https://colab.research.google.com/github/div-yash/Data-Science-Projects/blob/main/Restaurant%20Data%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING LIBRARIES :
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Dataset .csv")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Level 1
#
# Task 1 : Data Exploration and Preprocessing
#
# Aim :
#
# *   Explore the dataset and identify the number of rows and columns.
#
# *   Check for missing values in each column and handle them accordingly.
#
#
# *   Perform data type conversion if necessary.
# Analyze the distribution of the target variable
# ("Aggregate rating") and identify any class
# imbalances.

# %%
#exploring the dataset :
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#(No. of rows , No. of columns)
df.shape
# Out:
# (9551, 21)

# %%
#check for missing values :
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Here we can see Cuisines has 9 null values .

# %%
#handling the missing values :
df['Cuisines'].fillna('Not Specified',inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# checking the datatype of each columns :
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
target ="Aggregate rating"
print(df[target].describe())
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
#plotting the analysis on histogram :
plt.hist(x=df[target])
plt.title('Distribution of Aggregate Rating')
plt.xlabel('Aggregate rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Task 2 :Descriptive Analysis
#
# Aim :
#
# *   Calculate basic statistical measures (mean,median, standard deviation, etc.) for numerical columns.
# *   Explore the distribution of categorical
# variables like "Country Code," "City,and "Cuisines."
#
#
#
# *   Identify the top cuisines and cities with the highest number of restaurants.

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Numericals columns include : Average Cost for two ,Price range, Aggregate rating , Votes .
# Basic statistical measures (mean,median, standard deviation, etc.)
df[['Average Cost for two','Price range','Aggregate rating','Votes']].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# distribution of categorical variables like "Country Code," "City,and "Cuisines."

plt.figure(figsize=(10,5))
sns.countplot(x='Country Code',data=df,palette='cividis')
plt.title('Distribution of Country Code')
plt.xlabel('Country Code')
plt.ylabel('No. of Restruments')
plt.show()
# Out:
# <ipython-input-166-5385f16270bf>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Country Code',data=df,palette='cividis')

# %%
# top cuisines :
plt.figure(figsize=(15,8))
cc=df['Cuisines'].value_counts()
cc.head(20).plot(kind='bar',color=sns.color_palette('Set2'))
plt.title('Top Cuisines')
plt.xlabel('Cuisines')
plt.ylabel('No. of Restruments')
plt.show()

# %%
# cities with the highest number of restaurants :

cities=df['City'].value_counts().head(10)
print('Top cities with The Highest Number of Restruents :')
print(cities)
# Out:
# Top cities with The Highest Number of Restruents :
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %% [markdown]
# Task 3: Geospatial Analysis
#
# Aim :
#
# *
# Visualize the locations of restaurants on a
# map using latitude and longitude
# information.
# *   Analyze the distribution of restaurants
# across different cities or countries.
# Determine if there is any correlation
# between the restaurant's location and its
# rating.

# %%
#importing libraries for geospatial analysis :
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
#  the locations of restaurants on a map using latitude and longitude information.

gdf=gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df.Longitude,df.Latitude))
world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot('continent',legend="True",figsize=(18,15),marker='0',color='pink',markersize=10))
# Out:
# <ipython-input-170-a7294289e11e>:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# /usr/local/lib/python3.10/dist-packages/geopandas/plotting.py:658: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <Axes: >

# %%
# Analyze the distribution of restaurants across different cities :

plt.figure(figsize=(10,8))
sns.countplot(x=df['City'],order=df.City.value_counts().head(10).index,palette='Set2')
plt.title('Distribution of Restaurants across different cities')
plt.xlabel('Cities')
plt.ylabel('No. of Restruments')
plt.show()
# Out:
# <ipython-input-171-804eb006352c>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['City'],order=df.City.value_counts().head(10).index,palette='Set2')

# %%
plt.figure(figsize=(10,8))
cor_matrix =df[['Latitude','Longitude','Aggregate rating']].corr()
plt.title('Correlation between restaurants location and its rating ')
plt.xlabel('Number of Restaurents')
sns.heatmap(cor_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.show()

# %% [markdown]
# Level 2
#
# Task 1 : Table Booking and Online Delivery
#
# Aim :
#
# *   Determine the percentage of restaurants that
# offer table booking and online delivery.
# *   Compare the average ratings of restaurants
# with table booking and those without.
# *   Analyze the availability of online delivery
# among restaurants with different price ranges.

# %%
# restaurants that offer table booking .
df['Has Table booking'].value_counts()
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: count, dtype: int64

# %%
# percentage of restaurants that offer table booking .
print("table Booking : ",round(1158/(1158+8393)*100,2),"%")
# Out:
# table Booking :  12.12 %

# %%
# restaurants that offer online delivery :
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
# percentage of restaurants that offer online delivery :
print("Online Delivery : ",round(2451/(2451+7100)*100,2),"%")
# Out:
# Online Delivery :  25.66 %

# %%
# filter out dataframe for rows with yes and no in the table booking column :
df_table=df[df['Has Table booking']=='Yes']
df_notable=df[df['Has Table booking']=='No']

# %%
#printing out their shapes :

df_table.shape
# Out:
# (1158, 21)

# %%
df_notable.shape
# Out:
# (8393, 21)

# %%
# Comparing the average ratings of restaurants with table booking and those without.
print("Average Rating of restaurants with table booking : ",round(df_table['Aggregate rating'].mean(),2))
print("Average Rating of restaurants without table booking : ",round(df_notable['Aggregate rating'].mean(),2))
# Out:
# Average Rating of restaurants with table booking :  3.44
# Average Rating of restaurants without table booking :  2.56

# %%
# Group price range and calculate percentage of restaurants with online delivery :
online_deli_by_pr=df.groupby('Price range')['Has Online delivery'].value_counts(normalize=True).unstack()*100
online_deli_by_pr.plot(kind='bar',stacked=True,colormap='viridis',figsize=(10,8))
plt.title('Percentage of restaurants with online delivery among different price ranges')
plt.xlabel('Price range')
plt.ylabel('Percentage of restaurants')
plt.show()

# %%
# considering the restaurants with online delivery available :
online_deli=df[df['Has Online delivery']=='Yes']
online_deli_counts=online_deli.groupby(['Price range','Has Online delivery']).size().unstack()
online_deli_counts.plot(kind='bar',stacked=True,colormap='viridis',figsize=(10,8))
plt.title('Percentage of restaurants with online delivery among different price ranges')
plt.xlabel('Price range')
plt.ylabel('Percentage of restaurants')
plt.show()

# %% [markdown]
# Task 2 : Price Range Analysis
#
# Aim :
#
#
# *   Determine the most common price range
# among all the restaurants.
# *   Calculate the average rating for each price
# range.
# *   Identify the color that represents the highest
# average rating among different price ranges.

# %%
# most common price range among all the restaurants :
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
common =df["Price range"].mode()[0]
print("Most common price range among all the restaurants : ",common)
# Out:
# Most common price range among all the restaurants :  1

# %%
# Average rating for each price range.

avg_rating=df.groupby('Price range')['Aggregate rating'].mean().round(2)
print("Average rating for each price range : ",avg_rating)
# Out:
# Average rating for each price range :  Price range
# 1    2.00
# 2    2.94
# 3    3.68
# 4    3.82
# Name: Aggregate rating, dtype: float64

# %%
# price range with the highest average rating :
highest_avg_rating_color=avg_rating.idxmax()

plt.bar(avg_rating.index,avg_rating[highest_avg_rating_color],color='pink',width=0.5)

plt.xlabel('Price range')
plt.ylabel('Average rating')
plt.title('Price range with the highest average rating')
plt.show()

# %% [markdown]
# Task 3 : Feature Engineering
#
# Aim :
#
# *   Extract additional features from the existing
# columns, such as the length of the restaurant
# name or address.
# *   Create new features like "Has Table Booking"
# or "Has Online Delivery" by encoding
# categorical variables.

# %%
# Extract the length of the restaurant name or address :

df['Restaurant Name Length']=df['Restaurant Name'].apply(lambda x: len(str(x)))
df['Address Length']=df['Address'].apply(lambda x: len(str(x)))

# %%
df[['Restaurant Name','Restaurant Name Length','Address','Address Length']]
# Out:
#                Restaurant Name  Restaurant Name Length  \
# 0             Le Petit Souffle                      16
# 1             Izakaya Kikufuji                      16
# 2       Heat - Edsa Shangri-La                      22
# 3                         Ooma                       4
# 4                  Sambo Kojin                      11
# ...                        ...                     ...
# 9546               Naml۱ Gurme                      11
# 9547              Ceviz A��ac۱                      12
# 9548                     Huqqa                       5
# 9549               A���k Kahve                      11
# 9550  Walter's Coffee Roastery                      24
#
#                                                 Address  Address Length
# 0     Third Floor, Century City Mall, Kalayaan Avenu...              71
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...              67
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...              56
# ...

# %%
#Creating new features like "Has Table Booking" or "Has Online Delivery"

df['Has Table Booking']=df['Has Table booking'].apply(lambda x: 1 if x =='Yes' else 0)
df['Has Online Delivery']=df['Has Online delivery'].apply(lambda x: 1 if x =='Yes' else 0)

# %%
df[['Has Table booking','Has Table Booking','Has Online delivery','Has Online Delivery']]
# Out:
#      Has Table booking  Has Table Booking Has Online delivery  \
# 0                  Yes                  1                  No
# 1                  Yes                  1                  No
# 2                  Yes                  1                  No
# 3                   No                  0                  No
# 4                  Yes                  1                  No
# ...                ...                ...                 ...
# 9546                No                  0                  No
# 9547                No                  0                  No
# 9548                No                  0                  No
# 9549                No                  0                  No
# 9550                No                  0                  No
#
#       Has Online Delivery
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 9546                    0
# ...

# %% [markdown]
# Level 3
#
# Task 1: Predictive Modeling
#
# Aim :
#
#
# *   Build a regression model to predict the
# aggregate rating of a restaurant based on
# available features.
# Split the dataset into training and testing sets
# and evaluate the model's performance using
# appropriate metrics.
#
# *  Experiment with different algorithms (e.g.,
# linear regression, decision trees, random
# forest) and compare their performance.

# %%
# importing libraries :
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# converting categorical variables to numeric :
df=pd.get_dummies(df,columns=['Has Table booking','Has Online delivery'],drop_first=True)

# %%
# select features and target :
x= df[['Average Cost for two','Votes','Price range','Has Table booking_Yes','Has Online delivery_Yes']]
y=df['Aggregate rating']

# %%
# splitting the dataset into test and train data :
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# training the linear regression model :
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predicting ratings based on testing set :
y_pred=model.predict(x_test)

# %%
# checking the model's performance :
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error : ",mse)
print("R2 Score : ",r2)
# Out:
# Mean Squared Error :  1.6764802747031442
# R2 Score :  0.2634446409021949

# %%
# Initialize and train different regression models
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(random_state=42),
    'Random Forest': RandomForestRegressor(random_state=42)
}

# %%
# evaluating models :
results = {}
for name,model in models.items():
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  mse=mean_squared_error(y_test,y_pred)
  r2=r2_score(y_test,y_pred)
  results[name]={'MSE':mse,'R2 Score':r2}

# %%
# output :
results_df=pd.DataFrame(results)
print(results_df)
# Out:
#           Linear Regression  Decision Tree  Random Forest
# MSE                1.676480       0.203498       0.133938
# R2 Score           0.263445       0.910594       0.941155

# %% [markdown]
# Task 2: Customer Preference Analysis
#
# Aim :
#
#
# *   Analyze the relationship between the type of
# cuisine and the restaurant's rating.
# *   Identify the most popular cuisines among
# customers based on the number of votes.
# * Determine if there are any specific cuisines
# that tend to receive higher ratings.

# %%
# Analyze the relationship between the type of cuisine and the restaurant's rating :
cuisines = df['Cuisines']

# %%
cuisines.value_counts().head(10)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
# most popular cuisines among customers based on number of votes :
common_cuisines=cuisines.value_counts().head(10).index

# %%
# dataframe with cuisines types and corresponding ratings :
cuisines_ratings =pd.DataFrame({'Cuisine':cuisines,'Rating':df['Aggregate rating']})

# %%
# keeping only the top 10 cuisines :
cuisines_ratings_top=cuisines_ratings[cuisines_ratings['Cuisine'].isin(common_cuisines)]

# %%
# plot the relationship between the top 10 cuisine types and rating :
plt.figure(figsize=(12,6))
sns.boxplot(x='Cuisine',y='Rating',data=cuisines_ratings_top,order=common_cuisines)
plt.title('Relationship between the top 10 cuisine types and rating')
plt.xlabel('Cuisine')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %%
# identify the most popular cuisines among customers based on the number of votes :
# dataframe with cuisines and votes :
cuisines_votes =pd.DataFrame({'Cuisine':cuisines,'Votes':df['Votes']})

# %%
# grouping by cuisines and sum of votes for each cuisine :
cuisines_votes_grouped=cuisines_votes.groupby('Cuisine')['Votes'].sum()

# %%
# sorting cuisines based on total votes  (descending oreder)
cuisines_sorted=cuisines_votes_grouped.sort_values(ascending=False)

# %%
# display the sorted cuisines :
print("Top most popular cuisines among customers based on the number of votes :")
print(cuisines_sorted.head(10))
# Out:
# Top most popular cuisines among customers based on the number of votes :
# Cuisine
# North Indian, Mughlai             53747
# North Indian                      46241
# North Indian, Chinese             42012
# Cafe                              30657
# Chinese                           21925
# North Indian, Mughlai, Chinese    20115
# Fast Food                         17852
# South Indian                      16433
# Mughlai, North Indian             15275
# Italian                           14799
# Name: Votes, dtype: int64

# %%
# plotting the data into bar plot :
plt.figure(figsize=(12,6))
cuisines_sorted.head(10).plot(kind='bar',color='red')
plt.title('Most popular cuisines among customers based on the number of votes')
plt.xlabel('Cuisine')
plt.ylabel('Total Votes')
plt.show()

# %%
# dataframe with cuisines and ratings :
cuisines_ratings =pd.DataFrame({'Cuisine':cuisines,'Rating':df['Aggregate rating']})

# %%
# sorting the cusisines based on average rating (descending order):
cuisines_ratings_sorted=cuisines_ratings.groupby('Cuisine')['Rating'].mean().sort_values(ascending=False)

# %%
# show the top 10 cuisines with highest average ratings :
print("Top 10 cuisines with highest average ratings :")
print(cuisines_ratings_sorted.head(10))
# Out:
# Top 10 cuisines with highest average ratings :
# Cuisine
# Continental, Indian                4.9
# Hawaiian, Seafood                  4.9
# American, Burger, Grill            4.9
# European, Asian, Indian            4.9
# European, Contemporary             4.9
# American, Coffee and Tea           4.9
# American, Sandwich, Tea            4.9
# European, German                   4.9
# Mexican, American, Healthy Food    4.9
# Burger, Bar Food, Steak            4.9
# Name: Rating, dtype: float64

# %%
# Plotting the graph :
plt.figure(figsize=(12,6))
cuisines_ratings_sorted.head(10).plot(kind='barh',color='blue')
plt.title('Top 10 cuisines with highest average ratings')
plt.xlabel('Average Rating')
plt.ylabel('Cuisine')
plt.show()

# %% [markdown]
# Task3 : Data Visualization
#
# Aim :
#
#
# *   Create visualizations to represent the distribution
# of ratings using different charts (histogram, bar
# plot, etc.).
# *   Compare the average ratings of different cuisines
# or cities using appropriate visualizations.
# *  Visualize the relationship between various
# features and the target variable to gain insights.

# %%
# histogram to visualize the distribution of ratings :
plt.figure(figsize=(10,6))
sns.histplot(df['Aggregate rating'],bins=20,kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# bar plot to visualize the count of ratings :
plt.figure(figsize=(10,6))
sns.countplot(x='Aggregate rating',data=df)
plt.title('Count of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# create a box to visualize the distribution of ratings :
plt.figure(figsize=(10,6))
sns.boxplot(x='Aggregate rating',data=df)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.show()

# %%
# group data by city and calcualte the average  rating for each city :
average_rating_by_city=df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False)

# %%
# plot the average ratings of different cities :
plt.figure(figsize=(15,6))
sns.barplot(x=average_rating_by_city.head(10).index,y=average_rating_by_city.head(10).values,palette='viridis')
plt.title('Average Ratings of Different Cities')
plt.xlabel('City')
plt
# Out:
# <ipython-input-220-289caa3ac858>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_rating_by_city.head(10).index,y=average_rating_by_city.head(10).values,palette='viridis')
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
# pair plot : pairwise releationships between features and Aggregate rating :
sns.pairplot(df[['Average Cost for two','Price range','Aggregate rating','Has Table booking_Yes','Has Online delivery_Yes']])
plt.show()
